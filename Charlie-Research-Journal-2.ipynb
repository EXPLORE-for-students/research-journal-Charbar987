# %% [markdown]
# # Research Notebook
# ## Charlie Brooks
# ## Date: Feb 8th 2026

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# - took individual observvations taken on the same night, ensured they were close enough to each other
# - attempted to determine the H-α lines on each of the spectrum
# - Calculated the radial velocities for each of the spectra, and compared to the value given in IRAF
# - collected more star data to fill out the rotation curve plot
# - updated the code to be able to work properly with the gathered data from vizier
#
# ## Motivation:
#
# It was important to check that the observations were close enough to each other as we plan on taking the different observations and stacking them ontop of each other to increase the signal to noise ratio, to be able to more accurately determine values for HV4
#
# the H-α finding process is crucial to having a strong refenece point so that our radial velocity comes out as close as possible to the correct value. Stacking the different observations allows for an increase in the signal to noise ratio, letting us evaluate much more clearly where the H-α line truly lies
#
# We plan to collect a large number of RR Lyrae stars with known velocities, and be able to plot our RR Lyrae stars alongsidfe these other stars to be able to properly show their traits and compositons to create the most accurate estimate we can using these stars.

# %% [markdown]
# # <span style="color:magenta"> Notes </span>
# <span style="color:magenta"> Nice work! Why are you interested in the H-$\alpha$ lines in the first place? Is calculating the radial velocity the only application? [I assume this was likely mentioned in the first research journal, thus I won't deduce points for this, but ideally, these things should be to some degree self-contained.]
# </span>

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# The first iteration of trying to find the H-α lines left me with some values that were relatively close to each other and others that were much different, we need to be careful of how the images gets stacked or else the process will not accomplish any boost to the signal ratio. I intend to further invetigate the accuracy of the identified H-α lines to ensure that they are as close as possible. If this does not work it was also suggested that another way to improve the stacking could be to simply choose the best images where the H-α lines are the most prominent and stack only those images.
#
# The data collection for finding RR Lyrae stars inside the bulge has been tedious, it requires checking individual papers and the data they used to see if each star has been provided with data such as, parallax, radial velocity distances, etc. many of the stars analyzed are missing many of these components, typically the radial velocity.
#
# The code plotting the data provided had to be altered to be able to take in our own downloaded data and read off the properties correctly, it was also designed for the types of stars in the disk region so some parameters had to be changed to be able to

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
# The data was able to properly be plotted using the modified code, it is my intention to gather more data to fill out the visualization nicely, this graph demomnstrates the behaviour of already known RR Lyrae stars, our intention is to utilize this graph and plot and highlight our stars to observe how they compare with the trends of these other stars. Once the data is more complete the analysis of the data will become more concrete and conclusions will be able to be made

# %% [markdown]
# ![Screenshot 2026-02-09 at 8.44.36 AM.png](attachment:9d5f7ae0-89d2-493f-9f11-1a8e9a0c5b29.png)

# %% [markdown]
# | Reduced file number | IRAF wavelength | IRAF Radial Velocity | Calculated Radial Velocity |
# |--------------------|---------------------------------|-----------------------|-----------------|
# | HV4_1 | 656.708 | -464.52|-195.58 |
# | HV4_2 | 656.953 | 951.93 | -307.49|
# | HV4_3 | 656.543 |-351.66 | -120.2|
# | HV4_4 | 656.294 |-11.564 | -6.4|
# | HV4_5 | 656.154 | 260.56 | 57.6|
# | HV4_6 | 655.721 | -246.12| 255.64|

# %% [markdown]
# As you can see the radial velocities here are not very consistent with each other and they vary greatly into ranges they should not be in, I am going to attempt to resolve this by double checking the IRAF calculations to try and get the values more in line with what they should be.

# %% [markdown]
# # <span style="color:magenta"> Notes </span>
# <span style="color:magenta"> Here, I would've liked to see some concrete interpretation of the results. What does the plot mean? How does your data compare to other points on the plane? Why do you only have a y-Error?
# </span>

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# I plan on going back again and getting my images all stacked properly, with the h-α lined up correctly, hopefully this will allow the radial velocities to be much closer, however if this doesnt work, my plan is to make the stacked image with all of the best images, and that will greatly increase the s/n ratio

# %% [markdown]
# # 5. Bibliography
#
# Your references here

# %% [markdown]
# [1] - list of papers checked for RRL RV values: https://ui.adsabs.harvard.edu/search/filter_database_fq_database=AND&filter_database_fq_database=((database%3Aastronomy%20OR%20database%3Aphysics))&filter_database_fq_database=database%3A%22astronomy%22&fq=%7B!type%3Daqp%20v%3D%24fq_database%7D&fq_database=(((database%3Aastronomy%20OR%20database%3Aphysics))%20AND%20database%3A%22astronomy%22)&q=bulge%20&sort=date%20desc%2C%20bibcode%20desc&p_=0

# %% [markdown]
# | Category       | Points      |
# | ------------- |:------------:|
# | Formatting    |     2/2       |
# | Experience    |     2/2       |
# | What?         |     2/2       |
# | So what?      |     2/4       |
# | Now what?     |     4/4       |
# | Bibliography  |     3/3       |
# | Style         |     2/3       |
# | Total         |    17/20      |
