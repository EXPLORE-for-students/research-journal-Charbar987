# %% [markdown]
# # Research Notebook
# ## Charlie Brooks
# ## Date: March 11

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
# - Used the data reduction pipeline on a new star HV7
# - Compared reduced files to ensure the pipeline did not encounter any issues
# - Compute radial velocity of HV7
# - Calculated the phase of HV7
#
#
# ## Motivation:
#
# The decision to reduce and perform more data analysis on a new star was made after the two previous stars, HV4 and HV9 were both analyzed and there were difficulties in being able to extract reliable information with high clarity. The suggestion came after realizing that HV4 and HV9 were some of the dimmest stars in the survey. HV7 was chosen as its magnitude (~20.5) was approximately 1 unit greater than HV4 and HV9. We hoped that HV7 would provide much more promising results in term of the radial velocity, as it was a brighter object.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# Once the frames were reduced and we investigated the spectra for the H-α lines, we noticed that many of the lines were much more distinct than in previous stars. The star was calculated to have a more precise value for the radial velocity of approximately 90 km/s. The phase of the star was computed using the period and time of maximum brightness of the star. The reason for the phase calculation was to be able to see if the star was being observed at a time where its brightness was minimal, this would explain why the H-α lines seem to be much more difficult to find and work with. There was an issue with one of the reduced frames, and since my partner and I both had this error after doing our data reduction independently, we determined this was an issue with the observation itself, we questioned contacting Gemini to resolve this issue or at least to understand why this is happening. Another small issue was brought up that it seemed the second frame in every reduction seemed to have poor quality in its final product, however we brushed it off as being a coincidence as the issues were different for each star.

# %% [markdown]
# ![Screenshot 2026-03-11 at 7.40.41 PM.png](attachment:acf00bc6-7a1f-47de-a676-e8ef56b6fbef.png)

# %% [markdown]
# this table was used to collect some important pieces of information we found while analyzing our star. Including the wavelength, the velocity obtained from that wavelength, using the doppler shift formula, the signal to noise ratio s/n, we recorded this value to observe that the signal was better after stacking the two files.

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# The results of the reduction on the new star provides some information that is highly beneficial towards the research. The primary purpose of the activity was to determine if there were any issues with the observation itself or if the stars themselves were simply too dim to extract any meaningful interpretations. We were able to conclude that the reduction steps and analyzing for the H-α lines were done succesfully and without much issue. HV7 will also now be able to be added to our rotation curve model of the galaxy. With the rotation curve of the galaxy we hope to be able to use variable stars, RR Lyrae, as indicators as their periodic brightness and therefore well known distances allow us to be able to construct a model using them with (hopefully) a higher degree of accuracy than other models.

# %% [markdown]
# ![Screenshot 2026-03-11 at 2.25.07 PM.png](attachment:9098d335-a869-4b46-a7a5-4d0a2b50cb17.png)

# %% [markdown]
# This figure is from the stacked and shifted HV7 star frames that we deemed usuable in the identification of the H-α lines, you can see that after stacking and shifting the main absoption line is prominent in the exact spot where we would like to have found it, at 656.28 nm

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# We hope to be able to use the HV7 star to be able to shift the other stars in our survey, to see if we can get a more accurate determination of the H-α lines, we intend to accomplish this in IRAF using built-in features there. Once we are concluded with the spectra portion of the research, Dominik a mentor of the group, is preparing his code to simulate these RR lyrae stars in the Milky Way, we will gather many stars in different regions of the galaxy through research papers, we require these stars to have multiple specific data collected on them, primarily their Radial Velocities, paralax, distances, etc. These are the components required for the simulation to be as accurate as we wish.

# %% [markdown]
# # 5. Bibliography
#
# Your references here
